# %%
import csv
import sys
import subprocess
import shutil
from pathlib import Path

from PIL import Image
import torch
import torch.nn.functional as F
sys.path.append(str(Path().resolve().parent))
print(f"Adding to sys.path: {Path().resolve().parent.parent}")
from datamodule.transforms import get_val_transforms
from utils.model import get_model

# === CONFIG ===
MEAN = 0.37203550954887965
STD = 0.21801310757916936

PROJECT_ROOT = Path().resolve().parent
print(f"Project root: {PROJECT_ROOT}")
ONESHOT_PATH = PROJECT_ROOT / "explainability" / "LRP-for-ResNet" / "oneshot.py"
CONFIG_LRP_PATH = PROJECT_ROOT / "explainability" / "LRP-for-ResNet" / "configs" / "MGS_resnet18.json"
LABEL_CSV = PROJECT_ROOT / "data" / "MGS_data" / "labels" / "labels.csv"
IMAGE_DIR = PROJECT_ROOT / "data" / "MGS_data" / "data"
MODEL_PATH = PROJECT_ROOT / "results" / "run_2" / "config_20250617_220203" / "fold_0" / "best_model_epoch58_metric0.4497380901660238.pth"
CONFIG_PATH = PROJECT_ROOT / "results" / "run_2" / "config_20250617_220203" / "config.yaml"
TENSORBOARD_LOG_PATH = PROJECT_ROOT / "results" / "run_2" / "config_20250617_220203" / "fold_0" / "events.out.tfevents.1750190523.PCPatrick.37568.0"

OUTPUT_DIR = PROJECT_ROOT / "explainability" / "results" / "nbg"
sign_modes = ["all", "positive"]

# === PREP OUTPUT ===
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# === COPY MODEL TO RESULT DIR ===
shutil.copy(MODEL_PATH, OUTPUT_DIR / "best_model_epoch58_metric0.4497380901660238.pth")
shutil.copy(CONFIG_PATH, OUTPUT_DIR / "config.yaml")
shutil.copy(TENSORBOARD_LOG_PATH, OUTPUT_DIR / "events.out.tfevents.1750190523.PCPatrick.37568.0")


device = "cuda" if torch.cuda.is_available() else "cpu"
model = get_model({"pretrained": False, "num_classes": 2, "model_name": "resnet18"})
model.load_state_dict(torch.load(MODEL_PATH))
model = model.to(device)
model.eval()
transform = get_val_transforms(mean = MEAN, std = STD)

# === RUN ONESHOT FOR EACH IMAGE ===
with open(LABEL_CSV, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for i, row in enumerate(reader):
        filename = row["filename"]
        label = row["label"]
        image_path = IMAGE_DIR / filename
        
        if not image_path.exists():
            print(f"[WARN] Missing image: {image_path}")
            continue
        
        # make prediction
        img = Image.open(image_path).convert("L")
        img = transform(img)
        img = img.unsqueeze(0)  # Add batch dimension
        with torch.no_grad():
            result = model(img.to(device))
            probs = F.softmax(result, dim=1)[0] # probs for pain and no pain
            pred = torch.argmax(probs).item()  # Get the predicted class index
        prob_nopain = probs[0].item()  # Probability of no pain
        prob_pain = probs[1].item()  # Probability of pain
        


        
        image_path = IMAGE_DIR / filename

        for sign in sign_modes:
            output_dir = OUTPUT_DIR / f"sign_{sign}"
            output_dir.mkdir(parents=True, exist_ok=True)
            filename_stem = Path(filename).stem
            save_path = output_dir / (
                f"{filename_stem}_lrp_true{label}_painpred{prob_pain:.3f}_"
                f"nopainpred{prob_nopain:.3f}_sign{sign}.png"
            )
            print(f"Saving to: {save_path}")

            cmd = [
                "python", str(ONESHOT_PATH),
                "-c", str(CONFIG_LRP_PATH),
                "--method", "lrp",
                "--batch_size", "1",
                "--base_pretrained", str(MODEL_PATH),
                "--image-path", str(image_path),
                "--skip-connection-prop-type", "flows_skip",
                "--heat-quantization",
                "--label", str(label),
                "--sign", sign,
                "--save-path", str(save_path)
            ]

            print(f"[{sign.upper()}] Processing: {filename} with label {label}")
            subprocess.run(cmd)
            
        # if i == 10:
        #     print("Processed 10 images, stopping early for testing.")
        #     break
# Out:
# Adding to sys.path: C:\Users\Freun\Desktop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#      10 sys.path.append(str(Path().resolve().parent))
#      11 print(f"Adding to sys.path: {Path().resolve().parent.parent}")
# ---> 12 from datamodule.transforms import get_val_transforms
#      13 from utils.model import get_model
#      15 # === CONFIG ===
#
# File ~\Desktop\htcv_mgs\datamodule\transforms.py:15
#      13 import numpy as np
#      14 from PIL import Image, ImageFilter
# ---> 15 from torchvision import transforms
#      16 import torchvision.transforms.functional as F
#      17 import math
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\models\convnext.py:8
#       5 from torch import nn, Tensor
#       6 from torch.nn import functional as F
# ----> 8 from ..ops.misc import Conv2dNormActivation, Permute
#       9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: List[Tensor]) -> Tensor:
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\__init__.py:53
#      49 from .utils import graph_break_reasons, guard_failures, orig_code_map, reset_frame_count
#      52 # Register polyfill functions
# ---> 53 from .polyfills import loader as _  # usort: skip # noqa: F401
#      56 __all__ = [
#      57     "allow_in_graph",
#      58     "assume_constant_result",
#    (...)     82     "config",
#      83 ]
#      85 # allowlist this for weights_only load of NJTs
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\polyfills\loader.py:25
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)     23     "fx",
#      24 )
# ---> 25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
#      26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\polyfills\loader.py:26, in <genexpr>(.0)
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)     23     "fx",
#      24 )
#      25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
# ---> 26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\polyfills\builtins.py:30
#      19 __all__ = [
#      20     "all",
#      21     "any",
#      22     "enumerate",
#      23     "sum",
#      24 ]
#      27 _T = TypeVar("_T")
# ---> 30 @substitute_in_graph(builtins.all, can_constant_fold_through=True)
#      31 def all(iterable: Iterable[object], /) -> bool:
#      32     for elem in iterable:
#      33         if not elem:
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\decorators.py:427, in substitute_in_graph.<locals>.wrapper(traceable_fn)
#     424 if id(original_fn) in _polyfilled_function_ids:
#     425     raise ValueError(f"Duplicate polyfilled object {original_fn}")
# --> 427 rule_map: dict[Any, type[VariableTracker]] = get_torch_obj_rule_map()
#     428 if original_fn in rule_map:
#     429     raise ValueError(
#     430         f"Duplicate object {original_fn} with different rules: "
#     431         f"{PolyfilledFunctionVariable}, {rule_map[original_fn]}"
#     432     )
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\trace_rules.py:2870, in get_torch_obj_rule_map()
#    2868 for k, v in m.items():  # type: ignore[attr-defined]
#    2869     if ".py#" not in k:
# -> 2870         obj = load_object(k)
#    2871     else:
#    2872         obj = _module_dir(torch) + k[len("torch/") :]
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\trace_rules.py:2901, in load_object(name)
#    2899     else:
#    2900         assert len(x) == 1, f"Invalid obj name {name}"
# -> 2901         val = _load_obj_from_str(x[0])
#    2902     val = unwrap_if_wrapper(val)
#    2903 except (AttributeError, ImportError):
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_dynamo\trace_rules.py:2885, in _load_obj_from_str(fully_qualified_name)
#    2883 def _load_obj_from_str(fully_qualified_name):
#    2884     module, obj_name = fully_qualified_name.rsplit(".", maxsplit=1)
# -> 2885     return getattr(importlib.import_module(module), obj_name)
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_higher_order_ops\map.py:6
#       4 from torch._C import DispatchKey
#       5 from torch._dispatch.python import suspend_functionalization
# ----> 6 from torch._functorch.aot_autograd import AOTConfig, create_joint
#       7 from torch._higher_order_ops.utils import (
#       8     _has_potential_branch_input_alias,
#       9     _has_potential_branch_input_mutation,
#    (...)     12     UnsupportedAliasMutationException,
#      13 )
#      14 from torch._ops import HigherOrderOperator
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_functorch\aot_autograd.py:135
#     112 from ._aot_autograd.traced_function_transforms import (  # noqa: F401
#     113     aot_dispatch_subclass,
#     114     create_functional_call,
#    (...)    119     fn_prepped_for_autograd,
#     120 )
#     121 from ._aot_autograd.utils import (  # noqa: F401
#     122     _get_autocast_states,
#     123     _get_symint_hints,
#    (...)    133     strict_zip,
#     134 )
# --> 135 from .partitioners import default_partition
#     138 zip = strict_zip
#     140 # This global counter increments every time we compile a graph with
#     141 # AOTAutograd.  You can use this to correlate runtime error messages
#     142 # with compile time (e.g., if you get an error at runtime saying
#    (...)    149 # one counter is allocated per entire compiled block (but this block
#     150 # may involve compiling multiple subgraphs; e.g., for forwards/backwards)
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_functorch\partitioners.py:37
#      34 from torch.utils.checkpoint import CheckpointPolicy
#      36 from . import config
# ---> 37 from ._activation_checkpointing.graph_info_provider import GraphInfoProvider
#      38 from ._activation_checkpointing.knapsack import (
#      39     dp_knapsack,
#      40     greedy_knapsack,
#      41     ilp_knapsack,
#      42 )
#      43 from ._activation_checkpointing.knapsack_evaluator import KnapsackEvaluator
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\torch\_functorch\_activation_checkpointing\graph_info_provider.py:3
#       1 from typing import Any, Optional
# ----> 3 import networkx as nx
#       5 from torch.fx import Graph, Node
#       8 class GraphInfoProvider:
#
# File c:\Users\Freun\anaconda3\envs\HTCV_LRP\Lib\site-packages\networkx\__init__.py:29
#      26 from networkx import convert
#      27 from networkx.convert import *
# ---> 29 from networkx import convert_matrix
#      30 from networkx.convert_matrix import *
#      32 from networkx import relabel
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1532, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1506, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1605, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:
